# %%
from argparse import ArgumentParser
from collections import deque

import gymnasium as gym
import numpy as np
# import wandb

import torch
import torch.nn as nn
from torch.optim import Adam
from torch.optim.lr_scheduler import LinearLR
from torch.distributions.categorical import Categorical
import torch.nn.functional as F
import torch.optim as optim

# import pytorch_lightning as pl

# %%
MODEL_PATH = 'ppomodel.pth'

# %%
def get_device():
    """Gets the device (GPU if any) and logs the type"""
    if torch.cuda.is_available():
        device = torch.device("cuda")
        print(f"Found GPU device: {torch.cuda.get_device_name(device)}")
    else:
        device = torch.device("cpu")
        print("No GPU found: Running on CPU")
    return device

# %%
device = get_device()
device
# Out:
# No GPU found: Running on CPU
# device(type='cpu')

# %%
env = gym.make('Pendulum-v1')

# %%
class PPO(nn.Module): # definie the policy network
    def __init__(self, state_size=4, action_size=2, hidden_size=32):
        """Initialize the policy network
        
        Args:
            state_size (int): Dimension of the state space
            action_size (int): Dimension of the action space
            hidden_size (int): Number of neurons in the hidden layers"""
        super(PPO, self).__init__()
        
        # Attributes
        self.state_size = state_size
        self.action_size = action_size
        self.hidden_size = hidden_size
                
        # Actor
        self.actor = nn.Sequential(
            nn.Linear(state_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, action_size),
            nn.Softmax(dim=-1)
        )
        
        # Value function
        self.critic = nn.Sequential(
            nn.Linear(state_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, 1)
        )

    def forward(self, state):
        """Forward pass for both actor and critic
        
        Args:
            state (torch.Tensor): State tensor"""
        action = self.actor(state)
        value = self.critic(state)
        
        return action, value

    def act(self, state):
        """Take an action in the environment
        
        Args:
            state (np.array): Current state of the environment
            
        Returns:
            state (torch.Tensor): State tensor
            action (float): Action to take
            action_logtis (torch.Tensor): Logtis of the action
            value (torch.Tensor): Value of the state"""
        # Convert state to tensor for input of the network
        state = torch.from_numpy(state).float().unsqueeze(0).to(device)
        # get the action and the value
        action_logtis, value = self.forward(state)
        model = Categorical(action_logtis)
        action = model.sample()
        return state, action.item(), action_logtis, value

# %% [markdown]
# ## Get interactions with envrionment

# %%
@torch.no_grad()  # no gradient computation
def run_timesteps(env: gym.Env, model: PPO, max_t=1000) -> tuple:
    """Runs the given policy (model) on the environment for max_t timesteps
    
    Args:
        env (gym.Env): Environment to run the model on
        model (PPO): Policy to run
        max_t (int): Maximum number of timesteps to run
    
    Returns:
        actions (list): Actions taken by the model
        values (list): Values of the states
        rewards (list): Rewards obtained
        action_logits (list): Logits of the actions taken by the model
    """
    state = env.reset()[0]
    states = torch.Tensor(max_t, state.shape[0])
    actions = torch.Tensor(max_t)
    values = torch.Tensor(max_t)
    rewards = torch.Tensor(max_t)
    action_logits = torch.Tensor(max_t)
    for t in range(max_t):
        # Get the action, value and logtis
        input_state, action, action_logit, value = model.act(state)
        print(f"input_state: {input_state}, action: {action}, action_logit: {action_logit}, value: {value}")
        next_state, reward, done, _, _ = env.step([action])
        states[t] = (input_state)
        rewards[t] = (reward)
        action_logits[t] = (action_logit)
        actions[t] = (action)
        values[t] = (value)
        state = next_state
        if done:
            break
    return states, actions, values, rewards, action_logits

# %% [markdown]
# ## Compute the Loss

# %%
def get_losses(model: PPO, states: torch.Tensor, actions: torch.Tensor, action_logits: torch.Tensor, cumulative_rewards: torch.Tensor, values: torch.Tensor, epsilon: float, annealing: float) -> tuple:
    
    """Compute the losses for the PPO algorithm
    
    Args:
        model (PPO): Policy to train
        states (torch.Tensor): States of the environment
        actions (torch.Tensor): Actions taken
        action_logits (torch.Tensor): Logits of the actions taken
        cumulative_rewards (torch.Tensor): Cumulative rewards
        values (torch.Tensor): Values of the states
        epsilon (float): Clipping parameter
        annealing (float): Annealing parameter
        
    Returns:
        l_clip (torch.Tensor): Loss on the state-action-function
        l_vf (torch.Tensor): Loss on the value-function
        entropy_bonus (torch.Tensor): Bonus for the entropy of the actor"""
    
    # Computing predictions with the new model
    _, new_logits, new_values = model(states)

    # Loss on the state-action-function / actor (L_CLIP)
    advantages = cumulative_rewards - values
    margin = epsilon * annealing
    ratios = new_logits.gather(1, actions) / action_logits.gather(1, actions)

    l_clip = torch.mean(
        torch.min(
            torch.cat(
                (ratios * advantages,
                 torch.clip(ratios, 1 - margin, 1 + margin) * advantages),
                dim=1),
            dim=1
        ).values
    )

    # Loss on the value-function / critic (L_VF)
    l_vf = torch.mean((cumulative_rewards - new_values) ** 2)

    # Bonus for entropy of the actor
    entropy_bonus = torch.mean(torch.sum(-new_logits * (torch.log(new_logits + 1e-5)), dim=1))

    return l_clip, l_vf, entropy_bonus

# %% [markdown]
# # Training loop

# %%
def train(env: gym.Env, model: PPO, optimizer, epsilon, n_epochs, n_actors, batch_size, lr, c1, c2, render=False, early_stop=False, n_episodes=1000, max_t=1000, gamma=1.0, print_every=100):
    scores_deque = deque(maxlen=100)  # deque is a list-like container with fast appends and pops on either end
    scores = []
    anneals = np.linspace(1.0, 0.0, n_episodes)
    max_reward = -np.inf
    for iteration in range(1, n_episodes+1):
        print(f"Started iteration {iteration} / {n_episodes}")
        state = env.reset()
        
        buffer = []  # buffer = [[state], [action], [action_logit], [cumulative_rewards], [values
        for actor in range(n_actors):
            print(f"Running actor {actor + 1} / {n_actors}")
            # Collect trajectory for each actor
            state, action, values, rewards, action_logit = run_timesteps(env, model, max_t)
        
            # Calculate total expected reward
            scores_deque.append(sum(rewards))
            scores.append(sum(rewards))
            
            # Recalculate the total reward applying discounted factor
            discounts = [gamma ** i for i in range(len(rewards) + 1)]
            cum_discounted_rewards = [sum([discounts[j]*rewards[j+t] for j in range(len(rewards)-t) ]) for t in range(len(rewards))]

            # # compute Advantage
            # values = torch.cat(values)
            # advantages = cum_discounted_rewards - values
            
            buffer.append([state, action, action_logit, cum_discounted_rewards, values])
            print(f"Shape of buffer: {len(buffer[0])}")
            print(f"buffer: {buffer}")
        
        # Optimize loss over K epochs and minibatches
        for epoch in range(n_epochs):
            print(f"Optimizing epoch {epoch + 1} / {n_epochs}")
            for i in range(0, len(buffer)*max_t// batch_size):
                print(f"Optimizing minibatch {i + 1} / {len(buffer)// batch_size}")
                # Sample minibatch
                start = i * batch_size
                end = start + batch_size if start + batch_size < len(buffer) else len(buffer)
                # columns of buffer: state, action, action_logit, cum_discounted_rewards, values
                states = buffer[start:end][0]
                actions = buffer[start:end][1]
                action_logits = buffer[start:end][2]
                cumulative_rewards = buffer[start:end][3]
                values = buffer[start:end][4]
                               
                # Compute losses
                l_clip, l_vf, entropy_bonus = get_losses(model, states, actions, action_logits, cumulative_rewards, values, epsilon, anneals[iteration])
                
                # Optimize
                optimizer.zero_grad()
                loss = l_clip - c1*l_vf + c2*entropy_bonus
                loss.backward()
                optimizer.step()
        
        avg_rew = np.mean(scores_deque) 
        # Log scores
        if iteration % print_every == 0:
            curr_loss = loss.item()
            log = f"Iteration {iteration + 1} / {n_episodes}: " \
                    f"Average Reward: {avg_rew:.2f}\t" \
                    f"Loss: {curr_loss:.3f} " \
                    f"(L_CLIP: {l_clip.item():.1f} | L_VF: {l_vf.item():.1f} | L_bonus: {entropy_bonus.item():.1f})"
        
        if avg_rew > max_reward:
            torch.save(model.state_dict(), MODEL_PATH)
            max_reward = avg_rew
            log += " --> Stored model with highest average reward"
        if iteration % print_every == 0:
            print(log)
        
    return scores

# %%
model = PPO(state_size=env.observation_space.shape[0], action_size=env.action_space.shape[0]).to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)

scores = train(env, model, optimizer, epsilon=0.2, n_epochs=4, n_actors=4, batch_size=64, lr=1e-3, c1=1.0, c2=0.01, render=False, early_stop=False, n_episodes=1, max_t=1000, gamma=1.0, print_every=1)
# Out:
# Started iteration 1 / 1
# Running actor 1 / 4
# input_state: tensor([[ 0.8437, -0.5368, -0.2198]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.2601]])
# input_state: tensor([[ 0.8266, -0.5628, -0.6224]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.3347]])
# input_state: tensor([[ 0.7961, -0.6051, -1.0444]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.4136]])
# input_state: tensor([[ 0.7486, -0.6630, -1.4983]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.4863]])
# input_state: tensor([[ 0.6788, -0.7343, -1.9956]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.5620]])
# input_state: tensor([[ 0.5801, -0.8145, -2.5463]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.6387]])
# input_state: tensor([[ 0.4448, -0.8956, -3.1572]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.6958]])
# input_state: tensor([[ 0.2663, -0.9639, -3.8289]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7499]])
# input_state: tensor([[ 0.0419, -0.9991, -4.5518]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7939]])
# input_state: tensor([[-0.2213, -0.9752, -5.3012]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8340]])
# input_state: tensor([[-0.5010, -0.8655, -6.0326]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8702]])
# input_state: tensor([[-0.7571, -0.6533, -6.6817]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9033]])
# input_state: tensor([[-0.9382, -0.3461, -7.1717]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9418]])
# input_state: tensor([[-0.9998,  0.0182, -7.4312]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9999]])
# input_state: tensor([[-0.9253,  0.3793, -7.4176]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[1.0504]])
# input_state: tensor([[-0.7346,  0.6785, -7.1331]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[1.0836]])
# input_state: tensor([[-0.4740,  0.8805, -6.6242]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[1.0921]])
# input_state: tensor([[-0.1944,  0.9809, -5.9639]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[1.0513]])
# input_state: tensor([[ 0.0657,  0.9978, -5.2282]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9769]])
# input_state: tensor([[ 0.2857,  0.9583, -4.4798]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8946]])
# input_state: tensor([[ 0.4598,  0.8880, -3.7611]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8102]])
# input_state: tensor([[ 0.5912,  0.8065, -3.0950]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7275]])
# input_state: tensor([[ 0.6868,  0.7269, -2.4901]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.6351]])
# input_state: tensor([[ 0.7541,  0.6568, -1.9450]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.5494]])
# input_state: tensor([[ 0.7998,  0.6003, -1.4524]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.4711]])
# input_state: tensor([[ 0.8288,  0.5595, -1.0022]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.3848]])
# input_state: tensor([[ 0.8448,  0.5351, -0.5825]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.2856]])
# input_state: tensor([[ 0.8496,  0.5275, -0.1812]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.1871]])
# input_state: tensor([[0.8439, 0.5365, 0.2144]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.0743]])
# input_state: tensor([[0.8269, 0.5623, 0.6168]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.0794]])
# input_state: tensor([[0.7966, 0.6045, 1.0385]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.2130]])
# input_state: tensor([[0.7494, 0.6622, 1.4919]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.3247]])
# input_state: tensor([[0.6799, 0.7333, 1.9885]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.4435]])
# input_state: tensor([[0.5817, 0.8134, 2.5384]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.5896]])
# input_state: tensor([[0.4469, 0.8946, 3.1485]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.7849]])
# input_state: tensor([[0.2690, 0.9631, 3.8194]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.9992]])
# input_state: tensor([[0.0453, 0.9990, 4.5418]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.2331]])
# input_state: tensor([[-0.2175,  0.9761,  5.2910]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.4911]])
# input_state: tensor([[-0.4973,  0.8676,  6.0231]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.7421]])
# input_state: tensor([[-0.7540,  0.6569,  6.6738]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.9625]])
# input_state: tensor([[-0.9365,  0.3507,  7.1664]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-2.1242]])
# input_state: tensor([[-0.9999, -0.0131,  7.4295]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-2.2024]])
# input_state: tensor([[-0.9271, -0.3747,  7.4196]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-2.1824]])
# input_state: tensor([[-0.7378, -0.6751,  7.1386]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-2.0449]])
# input_state: tensor([[-0.4778, -0.8785,  6.6323]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.8399]])
# input_state: tensor([[-0.1982, -0.9802,  5.9735]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.5953]])
# input_state: tensor([[ 0.0624, -0.9981,  5.2383]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.3400]])
# input_state: tensor([[ 0.2830, -0.9591,  4.4898]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.0920]])
# input_state: tensor([[ 0.4577, -0.8891,  3.7705]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.8590]])
# input_state: tensor([[ 0.5897, -0.8077,  3.1036]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.6583]])
# input_state: tensor([[ 0.6857, -0.7279,  2.4979]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.4909]])
# input_state: tensor([[ 0.7533, -0.6576,  1.9520]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.3480]])
# input_state: tensor([[ 0.7993, -0.6010,  1.4588]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.2203]])
# input_state: tensor([[ 0.8285, -0.5600,  1.0080]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.0710]])
# input_state: tensor([[ 0.8446, -0.5354,  0.5881]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.0892]])
# input_state: tensor([[ 0.8496, -0.5275,  0.1865]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.1905]])
# input_state: tensor([[ 0.8440, -0.5363, -0.2090]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.2582]])
# input_state: tensor([[ 0.8272, -0.5618, -0.6113]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.3325]])
# input_state: tensor([[ 0.7971, -0.6038, -1.0327]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.4114]])
# input_state: tensor([[ 0.7501, -0.6613, -1.4855]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.4845]])
# input_state: tensor([[ 0.6811, -0.7322, -1.9815]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.5598]])
# input_state: tensor([[ 0.5832, -0.8123, -2.5306]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.6370]])
# input_state: tensor([[ 0.4490, -0.8935, -3.1399]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.6943]])
# input_state: tensor([[ 0.2717, -0.9624, -3.8100]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7486]])
# input_state: tensor([[ 0.0486, -0.9988, -4.5318]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7927]])
# input_state: tensor([[-0.2138, -0.9769, -5.2809]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8330]])
# input_state: tensor([[-0.4935, -0.8697, -6.0136]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8693]])
# input_state: tensor([[-0.7509, -0.6604, -6.6659]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9024]])
# input_state: tensor([[-0.9347, -0.3554, -7.1612]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9402]])
# input_state: tensor([[-1.0000,  0.0081, -7.4277]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9983]])
# input_state: tensor([[-0.9290,  0.3701, -7.4216]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[1.0492]])
# input_state: tensor([[-0.7409,  0.6716, -7.1440]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[1.0830]])
# input_state: tensor([[-0.4815,  0.8764, -6.6403]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[1.0922]])
# input_state: tensor([[-0.2019,  0.9794, -5.9830]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[1.0531]])
# input_state: tensor([[ 0.0591,  0.9983, -5.2485]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9791]])
# input_state: tensor([[ 0.2803,  0.9599, -4.4998]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8968]])
# input_state: tensor([[ 0.4557,  0.8901, -3.7799]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8124]])
# input_state: tensor([[ 0.5881,  0.8088, -3.1123]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7299]])
# input_state: tensor([[ 0.6846,  0.7289, -2.5057]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.6375]])
# input_state: tensor([[ 0.7526,  0.6585, -1.9590]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.5517]])
# input_state: tensor([[ 0.7988,  0.6016, -1.4651]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.4731]])
# input_state: tensor([[ 0.8282,  0.5604, -1.0139]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.3875]])
# input_state: tensor([[ 0.8445,  0.5356, -0.5936]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.2883]])
# input_state: tensor([[ 0.8496,  0.5274, -0.1919]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.1895]])
# input_state: tensor([[0.8442, 0.5361, 0.2037]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.0783]])
# input_state: tensor([[0.8276, 0.5614, 0.6057]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.0756]])
# input_state: tensor([[0.7977, 0.6031, 1.0268]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.2102]])
# input_state: tensor([[0.7509, 0.6604, 1.4791]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.3220]])
# input_state: tensor([[0.6822, 0.7312, 1.9744]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.4399]])
# input_state: tensor([[0.5848, 0.8112, 2.5228]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.5846]])
# input_state: tensor([[0.4511, 0.8925, 3.1312]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.7793]])
# input_state: tensor([[0.2744, 0.9616, 3.8006]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.9932]])
# input_state: tensor([[0.0519, 0.9987, 4.5218]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.2262]])
# input_state: tensor([[-0.2101,  0.9777,  5.2708]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.4841]])
# input_state: tensor([[-0.4898,  0.8718,  6.0040]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.7356]])
# input_state: tensor([[-0.7478,  0.6639,  6.6579]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.9572]])
# input_state: tensor([[-0.9330,  0.3600,  7.1559]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-2.1209]])
# input_state: tensor([[-1.0000e+00, -3.0273e-03,  7.4259e+00]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-2.2015]])
# input_state: tensor([[-0.9308, -0.3655,  7.4236]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-2.1849]])
# input_state: tensor([[-0.7441, -0.6681,  7.1494]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-2.0497]])
# input_state: tensor([[-0.4853, -0.8744,  6.6484]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.8461]])
# input_state: tensor([[-0.2056, -0.9786,  5.9926]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.6022]])
# input_state: tensor([[ 0.0558, -0.9984,  5.2586]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.3468]])
# input_state: tensor([[ 0.2777, -0.9607,  4.5098]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.0985]])
# input_state: tensor([[ 0.4536, -0.8912,  3.7893]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.8650]])
# input_state: tensor([[ 0.5866, -0.8099,  3.1209]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.6633]])
# input_state: tensor([[ 0.6835, -0.7300,  2.5135]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.4948]])
# input_state: tensor([[ 0.7518, -0.6594,  1.9660]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.3517]])
# input_state: tensor([[ 0.7983, -0.6023,  1.4715]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.2234]])
# input_state: tensor([[ 0.8279, -0.5608,  1.0197]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.0754]])
# input_state: tensor([[ 0.8443, -0.5358,  0.5991]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.0847]])
# input_state: tensor([[ 0.8496, -0.5274,  0.1973]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.1889]])
# input_state: tensor([[ 0.8443, -0.5358, -0.1983]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.2562]])
# input_state: tensor([[ 0.8279, -0.5609, -0.6002]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.3304]])
# input_state: tensor([[ 0.7982, -0.6024, -1.0209]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.4093]])
# input_state: tensor([[ 0.7517, -0.6595, -1.4727]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.4826]])
# input_state: tensor([[ 0.6833, -0.7302, -1.9674]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.5576]])
# input_state: tensor([[ 0.5863, -0.8101, -2.5150]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.6353]])
# input_state: tensor([[ 0.4532, -0.8914, -3.1226]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.6928]])
# input_state: tensor([[ 0.2771, -0.9608, -3.7911]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7474]])
# input_state: tensor([[ 0.0552, -0.9985, -4.5118]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7916]])
# input_state: tensor([[-0.2063, -0.9785, -5.2606]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8320]])
# input_state: tensor([[-0.4860, -0.8739, -5.9945]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8683]])
# input_state: tensor([[-0.7447, -0.6674, -6.6499]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9016]])
# input_state: tensor([[-0.9312, -0.3646, -7.1505]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9386]])
# input_state: tensor([[-1.0000e+00, -2.0200e-03, -7.4240e+00]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9968]])
# input_state: tensor([[-0.9326,  0.3609, -7.4255]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[1.0480]])
# input_state: tensor([[-0.7472,  0.6646, -7.1548]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[1.0823]])
# input_state: tensor([[-0.4890,  0.8723, -6.6563]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[1.0923]])
# input_state: tensor([[-0.2093,  0.9778, -6.0021]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[1.0549]])
# input_state: tensor([[ 0.0525,  0.9986, -5.2687]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9812]])
# input_state: tensor([[ 0.2750,  0.9615, -4.5198]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8991]])
# input_state: tensor([[ 0.4515,  0.8923, -3.7987]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8147]])
# input_state: tensor([[ 0.5851,  0.8110, -3.1295]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7322]])
# input_state: tensor([[ 0.6824,  0.7310, -2.5213]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.6400]])
# input_state: tensor([[ 0.7511,  0.6602, -1.9730]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.5539]])
# input_state: tensor([[ 0.7978,  0.6030, -1.4778]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.4752]])
# input_state: tensor([[ 0.8276,  0.5613, -1.0256]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.3903]])
# input_state: tensor([[ 0.8442,  0.5360, -0.6046]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.2910]])
# input_state: tensor([[ 0.8496,  0.5274, -0.2026]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.1919]])
# input_state: tensor([[0.8445, 0.5356, 0.1930]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.0823]])
# input_state: tensor([[0.8282, 0.5605, 0.5947]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.0717]])
# input_state: tensor([[0.7987, 0.6018, 1.0150]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.2074]])
# input_state: tensor([[0.7524, 0.6587, 1.4664]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.3193]])
# input_state: tensor([[0.6844, 0.7291, 1.9604]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.4363]])
# input_state: tensor([[0.5878, 0.8090, 2.5072]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.5801]])
# input_state: tensor([[0.4553, 0.8904, 3.1140]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.7738]])
# input_state: tensor([[0.2798, 0.9601, 3.7817]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.9871]])
# input_state: tensor([[0.0585, 0.9983, 4.5018]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.2193]])
# input_state: tensor([[-0.2026,  0.9793,  5.2505]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.4771]])
# input_state: tensor([[-0.4823,  0.8760,  5.9849]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.7291]])
# input_state: tensor([[-0.7415,  0.6709,  6.6419]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.9518]])
# input_state: tensor([[-0.9293,  0.3692,  7.1451]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-2.1174]])
# input_state: tensor([[-9.9998e-01,  7.0672e-03,  7.4220e+00]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-2.2006]])
# input_state: tensor([[-0.9344, -0.3563,  7.4273]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-2.1872]])
# input_state: tensor([[-0.7503, -0.6611,  7.1601]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-2.0543]])
# input_state: tensor([[-0.4928, -0.8702,  6.6643]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.8523]])
# input_state: tensor([[-0.2130, -0.9770,  6.0117]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.6090]])
# input_state: tensor([[ 0.0492, -0.9988,  5.2789]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.3536]])
# input_state: tensor([[ 0.2723, -0.9622,  4.5298]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.1051]])
# input_state: tensor([[ 0.4494, -0.8933,  3.8081]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.8711]])
# input_state: tensor([[ 0.5835, -0.8121,  3.1381]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.6684]])
# input_state: tensor([[ 0.6813, -0.7320,  2.5291]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.4988]])
# input_state: tensor([[ 0.7503, -0.6611,  1.9800]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.3554]])
# input_state: tensor([[ 0.7972, -0.6037,  1.4842]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.2265]])
# input_state: tensor([[ 0.8273, -0.5618,  1.0315]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.0797]])
# input_state: tensor([[ 0.8441, -0.5363,  0.6102]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.0802]])
# input_state: tensor([[ 0.8496, -0.5274,  0.2080]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.1872]])
# input_state: tensor([[ 0.8446, -0.5354, -0.1876]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.2542]])
# input_state: tensor([[ 0.8285, -0.5600, -0.5892]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.3283]])
# input_state: tensor([[ 0.7992, -0.6011, -1.0092]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.4072]])
# input_state: tensor([[ 0.7532, -0.6578, -1.4600]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.4808]])
# input_state: tensor([[ 0.6855, -0.7281, -1.9534]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.5554]])
# input_state: tensor([[ 0.5894, -0.8079, -2.4995]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.6336]])
# input_state: tensor([[ 0.4573, -0.8893, -3.1054]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.6913]])
# input_state: tensor([[ 0.2825, -0.9593, -3.7723]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7462]])
# input_state: tensor([[ 0.0617, -0.9981, -4.4918]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7904]])
# input_state: tensor([[-0.1989, -0.9800, -5.2404]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8309]])
# input_state: tensor([[-0.4785, -0.8781, -5.9754]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8674]])
# input_state: tensor([[-0.7384, -0.6744, -6.6339]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9007]])
# input_state: tensor([[-0.9275, -0.3738, -7.1397]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9370]])
# input_state: tensor([[-0.9999, -0.0121, -7.4200]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9953]])
# input_state: tensor([[-0.9361,  0.3517, -7.4291]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[1.0468]])
# input_state: tensor([[-0.7534,  0.6576, -7.1654]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[1.0817]])
# input_state: tensor([[-0.4965,  0.8680, -6.6722]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[1.0924]])
# input_state: tensor([[-0.2168,  0.9762, -6.0212]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[1.0567]])
# input_state: tensor([[ 0.0459,  0.9989, -5.2890]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9833]])
# input_state: tensor([[ 0.2695,  0.9630, -4.5398]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9014]])
# input_state: tensor([[ 0.4474,  0.8944, -3.8176]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8170]])
# input_state: tensor([[ 0.5820,  0.8132, -3.1468]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7344]])
# input_state: tensor([[ 0.6802,  0.7331, -2.5369]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.6424]])
# input_state: tensor([[ 0.7495,  0.6620, -1.9871]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.5561]])
# input_state: tensor([[ 0.7967,  0.6043, -1.4906]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.4772]])
# input_state: tensor([[ 0.8270,  0.5622, -1.0374]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.3930]])
# input_state: tensor([[ 0.8439,  0.5365, -0.6157]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.2937]])
# input_state: tensor([[ 0.8496,  0.5275, -0.2133]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.1944]])
# input_state: tensor([[0.8447, 0.5352, 0.1823]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.0863]])
# input_state: tensor([[0.8288, 0.5596, 0.5836]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.0678]])
# input_state: tensor([[0.7997, 0.6005, 1.0033]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.2045]])
# input_state: tensor([[0.7539, 0.6569, 1.4537]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.3166]])
# input_state: tensor([[0.6865, 0.7271, 1.9464]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.4327]])
# input_state: tensor([[0.5909, 0.8068, 2.4917]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.5756]])
# input_state: tensor([[0.4594, 0.8882, 3.0968]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.7683]])
# input_state: tensor([[0.2851, 0.9585, 3.7629]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.9810]])
# input_state: tensor([[0.0650, 0.9979, 4.4818]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.2125]])
# input_state: tensor([[-0.1952,  0.9808,  5.2302]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.4701]])
# input_state: tensor([[-0.4748,  0.8801,  5.9658]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.7226]])
# input_state: tensor([[-0.7352,  0.6778,  6.6259]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.9465]])
# input_state: tensor([[-0.9256,  0.3784,  7.1342]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-2.1140]])
# input_state: tensor([[-0.9999,  0.0172,  7.4180]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-2.1996]])
# input_state: tensor([[-0.9379, -0.3470,  7.4309]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-2.1888]])
# input_state: tensor([[-0.7565, -0.6540,  7.1706]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-2.0589]])
# input_state: tensor([[-0.5002, -0.8659,  6.6801]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.8584]])
# input_state: tensor([[-0.2205, -0.9754,  6.0307]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.6159]])
# input_state: tensor([[ 0.0426, -0.9991,  5.2991]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.3605]])
# input_state: tensor([[ 0.2668, -0.9637,  4.5498]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.1116]])
# input_state: tensor([[ 0.4453, -0.8954,  3.8270]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.8771]])
# input_state: tensor([[ 0.5804, -0.8143,  3.1555]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.6734]])
# input_state: tensor([[ 0.6790, -0.7341,  2.5447]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.5027]])
# input_state: tensor([[ 0.7487, -0.6629,  1.9941]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.3591]])
# input_state: tensor([[ 0.7962, -0.6050,  1.4970]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.2296]])
# input_state: tensor([[ 0.8267, -0.5627,  1.0432]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.0841]])
# input_state: tensor([[ 0.8438, -0.5367,  0.6212]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.0756]])
# input_state: tensor([[ 0.8496, -0.5275,  0.2187]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.1856]])
# input_state: tensor([[ 0.8449, -0.5350, -0.1769]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.2521]])
# input_state: tensor([[ 0.8291, -0.5592, -0.5781]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.3262]])
# input_state: tensor([[ 0.8002, -0.5998, -0.9975]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.4051]])
# input_state: tensor([[ 0.7547, -0.6561, -1.4473]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.4790]])
# input_state: tensor([[ 0.6876, -0.7261, -1.9394]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.5532]])
# input_state: tensor([[ 0.5924, -0.8057, -2.4839]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.6319]])
# input_state: tensor([[ 0.4614, -0.8872, -3.0882]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.6898]])
# input_state: tensor([[ 0.2878, -0.9577, -3.7536]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7449]])
# input_state: tensor([[ 0.0683, -0.9977, -4.4718]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7893]])
# input_state: tensor([[-0.1915, -0.9815, -5.2201]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8299]])
# input_state: tensor([[-0.4710, -0.8821, -5.9562]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8665]])
# input_state: tensor([[-0.7321, -0.6812, -6.6178]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8998]])
# input_state: tensor([[-0.9238, -0.3830, -7.1287]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9354]])
# input_state: tensor([[-0.9998, -0.0222, -7.4159]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9938]])
# input_state: tensor([[-0.9396,  0.3424, -7.4326]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[1.0456]])
# input_state: tensor([[-0.7595,  0.6505, -7.1758]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[1.0811]])
# input_state: tensor([[-0.5040,  0.8637, -6.6880]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[1.0924]])
# input_state: tensor([[-0.2243,  0.9745, -6.0402]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[1.0585]])
# input_state: tensor([[ 0.0393,  0.9992, -5.3093]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9855]])
# input_state: tensor([[ 0.2641,  0.9645, -4.5598]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9037]])
# input_state: tensor([[ 0.4431,  0.8965, -3.8365]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8192]])
# input_state: tensor([[ 0.5788,  0.8154, -3.1641]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7366]])
# input_state: tensor([[ 0.6779,  0.7351, -2.5526]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.6448]])
# input_state: tensor([[ 0.7480,  0.6637, -2.0012]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.5583]])
# input_state: tensor([[ 0.7957,  0.6057, -1.5034]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.4792]])
# input_state: tensor([[ 0.8264,  0.5631, -1.0491]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.3958]])
# input_state: tensor([[ 0.8436,  0.5370, -0.6268]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.2964]])
# input_state: tensor([[ 0.8496,  0.5275, -0.2241]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.1968]])
# input_state: tensor([[0.8450, 0.5347, 0.1715]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.0903]])
# input_state: tensor([[0.8294, 0.5587, 0.5726]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.0639]])
# input_state: tensor([[0.8006, 0.5991, 0.9916]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.2008]])
# input_state: tensor([[0.7554, 0.6552, 1.4410]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.3140]])
# input_state: tensor([[0.6887, 0.7250, 1.9324]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.4292]])
# input_state: tensor([[0.5939, 0.8045, 2.4762]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.5712]])
# input_state: tensor([[0.4635, 0.8861, 3.0796]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.7628]])
# input_state: tensor([[0.2905, 0.9569, 3.7442]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.9750]])
# input_state: tensor([[0.0716, 0.9974, 4.4618]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.2058]])
# input_state: tensor([[-0.1878,  0.9822,  5.2099]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.4632]])
# input_state: tensor([[-0.4673,  0.8841,  5.9466]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.7160]])
# input_state: tensor([[-0.7289,  0.6846,  6.6097]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.9410]])
# input_state: tensor([[-0.9219,  0.3875,  7.1231]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-2.1104]])
# input_state: tensor([[-0.9996,  0.0273,  7.4138]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-2.1985]])
# input_state: tensor([[-0.9413, -0.3377,  7.4342]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-2.1904]])
# input_state: tensor([[-0.7626, -0.6469,  7.1810]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-2.0635]])
# input_state: tensor([[-0.5077, -0.8615,  6.6958]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.8645]])
# input_state: tensor([[-0.2280, -0.9737,  6.0496]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.6228]])
# input_state: tensor([[ 0.0359, -0.9994,  5.3194]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.3673]])
# input_state: tensor([[ 0.2614, -0.9652,  4.5699]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.1182]])
# input_state: tensor([[ 0.4410, -0.8975,  3.8459]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.8832]])
# input_state: tensor([[ 0.5773, -0.8166,  3.1728]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.6785]])
# input_state: tensor([[ 0.6768, -0.7362,  2.5604]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.5067]])
# input_state: tensor([[ 0.7472, -0.6646,  2.0083]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.3628]])
# input_state: tensor([[ 0.7952, -0.6064,  1.5098]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.2327]])
# input_state: tensor([[ 0.8260, -0.5636,  1.0550]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.0884]])
# input_state: tensor([[ 0.8435, -0.5372,  0.6323]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.0707]])
# input_state: tensor([[ 0.8496, -0.5275,  0.2294]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.1839]])
# input_state: tensor([[ 0.8451, -0.5345, -0.1662]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.2499]])
# input_state: tensor([[ 0.8297, -0.5583, -0.5671]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.3240]])
# input_state: tensor([[ 0.8011, -0.5985, -0.9858]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.4030]])
# input_state: tensor([[ 0.7562, -0.6544, -1.4347]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.4772]])
# input_state: tensor([[ 0.6898, -0.7240, -1.9254]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.5510]])
# input_state: tensor([[ 0.5954, -0.8034, -2.4685]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.6302]])
# input_state: tensor([[ 0.4655, -0.8850, -3.0710]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.6883]])
# input_state: tensor([[ 0.2931, -0.9561, -3.7348]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7437]])
# input_state: tensor([[ 0.0748, -0.9972, -4.4519]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7881]])
# input_state: tensor([[-0.1841, -0.9829, -5.1998]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8288]])
# input_state: tensor([[-0.4635, -0.8861, -5.9370]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8655]])
# input_state: tensor([[-0.7257, -0.6880, -6.6015]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8989]])
# input_state: tensor([[-0.9199, -0.3921, -7.1175]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9339]])
# input_state: tensor([[-0.9995, -0.0323, -7.4116]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9922]])
# input_state: tensor([[-0.9429,  0.3330, -7.4358]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[1.0444]])
# input_state: tensor([[-0.7656,  0.6433, -7.1861]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[1.0804]])
# input_state: tensor([[-0.5114,  0.8593, -6.7036]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[1.0925]])
# input_state: tensor([[-0.2317,  0.9728, -6.0591]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[1.0603]])
# input_state: tensor([[ 0.0326,  0.9995, -5.3295]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9876]])
# input_state: tensor([[ 0.2586,  0.9660, -4.5799]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9059]])
# input_state: tensor([[ 0.4389,  0.8985, -3.8554]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8215]])
# input_state: tensor([[ 0.5757,  0.8177, -3.1815]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7388]])
# input_state: tensor([[ 0.6757,  0.7372, -2.5683]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.6473]])
# input_state: tensor([[ 0.7464,  0.6655, -2.0154]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.5606]])
# input_state: tensor([[ 0.7947,  0.6071, -1.5162]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.4813]])
# input_state: tensor([[ 0.8257,  0.5641, -1.0609]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.3985]])
# input_state: tensor([[ 0.8433,  0.5375, -0.6379]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.2991]])
# input_state: tensor([[ 0.8495,  0.5275, -0.2348]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.1992]])
# input_state: tensor([[0.8453, 0.5343, 0.1608]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.0940]])
# input_state: tensor([[0.8299, 0.5579, 0.5616]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.0601]])
# input_state: tensor([[0.8016, 0.5978, 0.9800]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.1971]])
# input_state: tensor([[0.7569, 0.6535, 1.4284]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.3113]])
# input_state: tensor([[0.6908, 0.7230, 1.9185]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.4256]])
# input_state: tensor([[0.5969, 0.8023, 2.4607]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.5668]])
# input_state: tensor([[0.4675, 0.8840, 3.0625]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.7574]])
# input_state: tensor([[0.2957, 0.9553, 3.7255]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.9689]])
# input_state: tensor([[0.0781, 0.9969, 4.4419]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.1994]])
# input_state: tensor([[-0.1804,  0.9836,  5.1896]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.4562]])
# input_state: tensor([[-0.4598,  0.8880,  5.9273]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.7094]])
# input_state: tensor([[-0.7225,  0.6914,  6.5934]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.9355]])
# input_state: tensor([[-0.9180,  0.3966,  7.1119]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-2.1068]])
# input_state: tensor([[-0.9993,  0.0373,  7.4094]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-2.1974]])
# input_state: tensor([[-0.9446, -0.3283,  7.4374]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-2.1919]])
# input_state: tensor([[-0.7686, -0.6397,  7.1911]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-2.0680]])
# input_state: tensor([[-0.5151, -0.8571,  6.7114]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.8706]])
# input_state: tensor([[-0.2355, -0.9719,  6.0685]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.6296]])
# input_state: tensor([[ 0.0293, -0.9996,  5.3396]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.3741]])
# input_state: tensor([[ 0.2559, -0.9667,  4.5899]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.1248]])
# input_state: tensor([[ 0.4368, -0.8996,  3.8649]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.8893]])
# input_state: tensor([[ 0.5741, -0.8188,  3.1902]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.6835]])
# input_state: tensor([[ 0.6745, -0.7383,  2.5761]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.5107]])
# input_state: tensor([[ 0.7456, -0.6664,  2.0225]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.3665]])
# input_state: tensor([[ 0.7941, -0.6077,  1.5227]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.2358]])
# input_state: tensor([[ 0.8254, -0.5645,  1.0668]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.0928]])
# input_state: tensor([[ 0.8431, -0.5377,  0.6434]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.0658]])
# input_state: tensor([[ 0.8495, -0.5275,  0.2402]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.1822]])
# input_state: tensor([[ 0.8454, -0.5341, -0.1555]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.2476]])
# input_state: tensor([[ 0.8302, -0.5574, -0.5561]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.3219]])
# input_state: tensor([[ 0.8021, -0.5972, -0.9742]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.4009]])
# input_state: tensor([[ 0.7577, -0.6527, -1.4220]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.4754]])
# input_state: tensor([[ 0.6919, -0.7220, -1.9115]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.5488]])
# input_state: tensor([[ 0.5984, -0.8012, -2.4530]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.6284]])
# input_state: tensor([[ 0.4696, -0.8829, -3.0539]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.6868]])
# input_state: tensor([[ 0.2984, -0.9545, -3.7161]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7423]])
# input_state: tensor([[ 0.0813, -0.9967, -4.4320]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7870]])
# input_state: tensor([[-0.1767, -0.9843, -5.1795]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8278]])
# input_state: tensor([[-0.4560, -0.8900, -5.9177]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8646]])
# input_state: tensor([[-0.7193, -0.6947, -6.5852]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8981]])
# input_state: tensor([[-0.9160, -0.4011, -7.1062]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9323]])
# input_state: tensor([[-0.9991, -0.0424, -7.4071]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9907]])
# input_state: tensor([[-0.9462,  0.3236, -7.4389]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[1.0432]])
# input_state: tensor([[-0.7717,  0.6360, -7.1961]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[1.0797]])
# input_state: tensor([[-0.5188,  0.8549, -6.7191]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[1.0925]])
# input_state: tensor([[-0.2392,  0.9710, -6.0780]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[1.0621]])
# input_state: tensor([[ 0.0259,  0.9997, -5.3497]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9897]])
# input_state: tensor([[ 0.2531,  0.9674, -4.6000]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9082]])
# input_state: tensor([[ 0.4346,  0.9006, -3.8744]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8238]])
# input_state: tensor([[ 0.5725,  0.8199, -3.1990]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7409]])
# input_state: tensor([[ 0.6734,  0.7393, -2.5840]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.6497]])
# input_state: tensor([[ 0.7448,  0.6673, -2.0296]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.5628]])
# input_state: tensor([[ 0.7936,  0.6084, -1.5291]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.4833]])
# input_state: tensor([[ 0.8251,  0.5650, -1.0728]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.4013]])
# input_state: tensor([[ 0.8430,  0.5380, -0.6490]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.3018]])
# input_state: tensor([[ 0.8495,  0.5276, -0.2455]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.2017]])
# input_state: tensor([[0.8455, 0.5339, 0.1501]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.0976]])
# input_state: tensor([[0.8305, 0.5570, 0.5506]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.0562]])
# input_state: tensor([[0.8026, 0.5965, 0.9683]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.1934]])
# input_state: tensor([[0.7584, 0.6518, 1.4157]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.3087]])
# input_state: tensor([[0.6930, 0.7210, 1.9046]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.4221]])
# input_state: tensor([[0.5999, 0.8001, 2.4453]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.5624]])
# input_state: tensor([[0.4716, 0.8818, 3.0454]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.7519]])
# input_state: tensor([[0.3010, 0.9536, 3.7068]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.9629]])
# input_state: tensor([[0.0845, 0.9964, 4.4220]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.1930]])
# input_state: tensor([[-0.1730,  0.9849,  5.1693]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.4492]])
# input_state: tensor([[-0.4522,  0.8919,  5.9080]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.7028]])
# input_state: tensor([[-0.7160,  0.6981,  6.5769]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.9300]])
# input_state: tensor([[-0.9140,  0.4056,  7.1005]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-2.1031]])
# input_state: tensor([[-0.9989,  0.0474,  7.4047]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-2.1961]])
# input_state: tensor([[-0.9478, -0.3189,  7.4403]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-2.1933]])
# input_state: tensor([[-0.7747, -0.6324,  7.2011]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-2.0725]])
# input_state: tensor([[-0.5225, -0.8526,  6.7268]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.8766]])
# input_state: tensor([[-0.2430, -0.9700,  6.0874]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.6365]])
# input_state: tensor([[ 0.0225, -0.9997,  5.3598]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.3809]])
# input_state: tensor([[ 0.2503, -0.9682,  4.6100]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.1314]])
# input_state: tensor([[ 0.4325, -0.9016,  3.8839]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.8954]])
# input_state: tensor([[ 0.5709, -0.8210,  3.2077]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.6886]])
# input_state: tensor([[ 0.6722, -0.7403,  2.5919]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.5147]])
# input_state: tensor([[ 0.7440, -0.6682,  2.0367]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.3703]])
# input_state: tensor([[ 0.7931, -0.6091,  1.5355]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.2390]])
# input_state: tensor([[ 0.8247, -0.5655,  1.0787]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.0971]])
# input_state: tensor([[ 0.8428, -0.5382,  0.6546]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.0608]])
# input_state: tensor([[ 0.8495, -0.5276,  0.2509]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.1806]])
# input_state: tensor([[ 0.8457, -0.5337, -0.1448]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.2454]])
# input_state: tensor([[ 0.8308, -0.5566, -0.5451]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.3198]])
# input_state: tensor([[ 0.8031, -0.5959, -0.9625]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.3988]])
# input_state: tensor([[ 0.7591, -0.6510, -1.4094]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.4736]])
# input_state: tensor([[ 0.6940, -0.7200, -1.8977]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.5466]])
# input_state: tensor([[ 0.6013, -0.7990, -2.4376]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.6267]])
# input_state: tensor([[ 0.4736, -0.8808, -3.0369]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.6853]])
# input_state: tensor([[ 0.3036, -0.9528, -3.6975]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7408]])
# input_state: tensor([[ 0.0877, -0.9961, -4.4121]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7858]])
# input_state: tensor([[-0.1693, -0.9856, -5.1592]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8267]])
# ...
# input_state: tensor([[0.2887, 0.9574, 1.3266]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.3130]])
# input_state: tensor([[0.1895, 0.9819, 2.0446]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.4946]])
# input_state: tensor([[0.0516, 0.9987, 2.7811]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.6925]])
# input_state: tensor([[-0.1246,  0.9922,  3.5301]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.9270]])
# input_state: tensor([[-0.3322,  0.9432,  4.2742]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.1712]])
# input_state: tensor([[-0.5544,  0.8322,  4.9816]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.4103]])
# input_state: tensor([[-0.7630,  0.6464,  5.6058]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.6196]])
# input_state: tensor([[-0.9217,  0.3879,  6.0906]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.7786]])
# input_state: tensor([[-0.9969,  0.0791,  6.3815]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.8681]])
# input_state: tensor([[-0.9707, -0.2404,  6.4408]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.8760]])
# input_state: tensor([[-0.8495, -0.5277,  6.2605]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.7878]])
# input_state: tensor([[-0.6607, -0.7507,  5.8648]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.6219]])
# input_state: tensor([[-0.4409, -0.8975,  5.3018]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.4079]])
# input_state: tensor([[-0.2233, -0.9747,  4.6286]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.1666]])
# input_state: tensor([[-0.0303, -0.9995,  3.8975]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.9200]])
# input_state: tensor([[ 0.1267, -0.9919,  3.1479]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.6728]])
# input_state: tensor([[ 0.2448, -0.9696,  2.4039]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.4653]])
# input_state: tensor([[ 0.3251, -0.9457,  1.6767]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.2874]])
# input_state: tensor([[ 0.3704, -0.9289,  0.9675]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.0757]])
# input_state: tensor([[ 0.3830, -0.9238,  0.2708]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.1094]])
# input_state: tensor([[ 0.3634, -0.9316, -0.4220]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.2667]])
# input_state: tensor([[ 0.3107, -0.9505, -1.1207]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.3759]])
# input_state: tensor([[ 0.2223, -0.9750, -1.8336]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.4607]])
# input_state: tensor([[ 0.0958, -0.9954, -2.5648]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.5377]])
# input_state: tensor([[-0.0695, -0.9976, -3.3114]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.6056]])
# input_state: tensor([[-0.2692, -0.9631, -4.0596]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.6607]])
# input_state: tensor([[-0.4896, -0.8719, -4.7819]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7084]])
# input_state: tensor([[-0.7057, -0.7085, -5.4358]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7499]])
# input_state: tensor([[-0.8828, -0.4697, -5.9672]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7858]])
# input_state: tensor([[-0.9851, -0.1721, -6.3195]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8373]])
# input_state: tensor([[-0.9889,  0.1489, -6.4486]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8860]])
# input_state: tensor([[-0.8933,  0.4496, -6.3369]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9220]])
# input_state: tensor([[-0.7205,  0.6934, -5.9997]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9388]])
# input_state: tensor([[-0.5060,  0.8625, -5.4797]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9328]])
# input_state: tensor([[-0.2849,  0.9586, -4.8328]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8742]])
# input_state: tensor([[-0.0831,  0.9965, -4.1139]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7954]])
# input_state: tensor([[ 0.0850,  0.9964, -3.3664]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7074]])
# input_state: tensor([[ 0.2144,  0.9768, -2.6192]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.5982]])
# input_state: tensor([[ 0.3054,  0.9522, -1.8866]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.4729]])
# input_state: tensor([[ 0.3607,  0.9327, -1.1724]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.3439]])
# input_state: tensor([[ 0.3826,  0.9239, -0.4729]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.2024]])
# input_state: tensor([[0.3725, 0.9281, 0.2200]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.0003]])
# input_state: tensor([[0.3296, 0.9441, 0.9160]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.2158]])
# input_state: tensor([[0.2519, 0.9678, 1.6241]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.3822]])
# input_state: tensor([[0.1367, 0.9906, 2.3500]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.5760]])
# input_state: tensor([[-0.0175,  0.9998,  3.0929]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.7893]])
# input_state: tensor([[-0.2081,  0.9781,  3.8428]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.0251]])
# input_state: tensor([[-0.4245,  0.9054,  4.5764]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.2734]])
# input_state: tensor([[-0.6452,  0.7640,  5.2554]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.5025]])
# input_state: tensor([[-0.8375,  0.5465,  5.8285]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.6933]])
# input_state: tensor([[-0.9648,  0.2631,  6.2383]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.8253]])
# input_state: tensor([[-0.9985, -0.0555,  6.4356]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.8817]])
# input_state: tensor([[-0.9304, -0.3665,  6.3940]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.8544]])
# input_state: tensor([[-0.7768, -0.6297,  6.1191]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.7257]])
# input_state: tensor([[-0.5706, -0.8212,  5.6468]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.5372]])
# input_state: tensor([[-0.3482, -0.9374,  5.0309]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.3094]])
# input_state: tensor([[-0.1389, -0.9903,  4.3278]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.0643]])
# input_state: tensor([[ 0.0399, -0.9992,  3.5851]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.8164]])
# input_state: tensor([[ 0.1807, -0.9835,  2.8357]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.5748]])
# input_state: tensor([[ 0.2827, -0.9592,  2.0981]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.3906]])
# input_state: tensor([[ 0.3481, -0.9374,  1.3787]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.2087]])
# input_state: tensor([[ 0.3796, -0.9252,  0.6756]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.0053]])
# input_state: tensor([[ 0.3787, -0.9255, -0.0183]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.1717]])
# input_state: tensor([[ 0.3455, -0.9384, -0.7124]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.3129]])
# input_state: tensor([[ 0.2783, -0.9605, -1.4162]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.4177]])
# input_state: tensor([[ 0.1743, -0.9847, -2.1366]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.4935]])
# input_state: tensor([[ 0.0314, -0.9995, -2.8751]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.5683]])
# input_state: tensor([[-0.1493, -0.9888, -3.6248]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.6297]])
# input_state: tensor([[-0.3599, -0.9330, -4.3664]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.6814]])
# input_state: tensor([[-0.5822, -0.8130, -5.0661]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7265]])
# input_state: tensor([[-0.7866, -0.6175, -5.6759]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7655]])
# input_state: tensor([[-0.9364, -0.3510, -6.1390]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8057]])
# input_state: tensor([[-0.9993, -0.0385, -6.4022]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8587]])
# input_state: tensor([[-0.9602,  0.2793, -6.4311]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9030]])
# input_state: tensor([[-0.8286,  0.5598, -6.2216]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9316]])
# input_state: tensor([[-0.6339,  0.7734, -5.8018]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9391]])
# input_state: tensor([[-0.4128,  0.9108, -5.2217]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9140]])
# input_state: tensor([[-0.1973,  0.9804, -4.5386]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8427]])
# input_state: tensor([[-0.0084,  1.0000, -3.8033]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7595]])
# input_state: tensor([[ 0.1438,  0.9896, -3.0533]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.6667]])
# input_state: tensor([[ 0.2569,  0.9664, -2.3111]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.5482]])
# input_state: tensor([[ 0.3327,  0.9430, -1.5863]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.4159]])
# input_state: tensor([[ 0.3738,  0.9275, -0.8790]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.2880]])
# input_state: tensor([[ 0.3823,  0.9240, -0.1834]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.1193]])
# input_state: tensor([[0.3586, 0.9335, 0.5096]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.0865]])
# input_state: tensor([[0.3015, 0.9535, 1.2098]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.2869]])
# input_state: tensor([[0.2085, 0.9780, 1.9249]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.4625]])
# input_state: tensor([[0.0771, 0.9970, 2.6584]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.6581]])
# input_state: tensor([[-0.0930,  0.9957,  3.4061]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.8880]])
# input_state: tensor([[-0.2963,  0.9551,  4.1529]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.1301]])
# input_state: tensor([[-0.5178,  0.8555,  4.8692]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.3724]])
# input_state: tensor([[-0.7310,  0.6824,  5.5108]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.5880]])
# input_state: tensor([[-0.9005,  0.4348,  6.0226]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.7567]])
# input_state: tensor([[-0.9912,  0.1320,  6.3487]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.8588]])
# input_state: tensor([[-0.9820, -0.1888,  6.4477]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.8805]])
# input_state: tensor([[-0.8750, -0.4840,  6.3061]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.8092]])
# input_state: tensor([[-0.6950, -0.7190,  5.9431]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.6532]])
# input_state: tensor([[-0.4778, -0.8785,  5.4038]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.4457]])
# input_state: tensor([[-0.2580, -0.9662,  4.7450]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-1.2073]])
# input_state: tensor([[-0.0599, -0.9982,  4.0203]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.9610]])
# input_state: tensor([[ 0.1035, -0.9946,  3.2717]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.7133]])
# input_state: tensor([[ 0.2279, -0.9737,  2.5257]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.4939]])
# input_state: tensor([[ 0.3143, -0.9493,  1.7955]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.3165]])
# input_state: tensor([[ 0.3653, -0.9309,  1.0835]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[-0.1110]])
# input_state: tensor([[ 0.3831, -0.9237,  0.3853]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.0793]])
# input_state: tensor([[ 0.3689, -0.9295, -0.3075]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.2463]])
# input_state: tensor([[ 0.3217, -0.9468, -1.0046]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.3582]])
# input_state: tensor([[ 0.2395, -0.9709, -1.7147]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.4481]])
# input_state: tensor([[ 0.1194, -0.9928, -2.4429]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.5253]])
# input_state: tensor([[-0.0397, -0.9992, -3.1875]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.5958]])
# input_state: tensor([[-0.2343, -0.9722, -3.9369]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.6521]])
# input_state: tensor([[-0.4527, -0.8916, -4.6660]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7010]])
# input_state: tensor([[-0.6718, -0.7408, -5.3348]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7435]])
# input_state: tensor([[-0.8579, -0.5139, -5.8904]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7802]])
# input_state: tensor([[-0.9746, -0.2240, -6.2758]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8285]])
# input_state: tensor([[-0.9954,  0.0961, -6.4438]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8787]])
# input_state: tensor([[-0.9152,  0.4031, -6.3717]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9172]])
# input_state: tensor([[-0.7529,  0.6581, -6.0694]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9376]])
# input_state: tensor([[-0.5427,  0.8399, -5.5758]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.9354]])
# input_state: tensor([[-0.3206,  0.9472, -4.9459]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8860]])
# input_state: tensor([[-0.1144,  0.9934, -4.2355]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.8091]])
# input_state: tensor([[ 0.0599,  0.9982, -3.4904]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.7224]])
# input_state: tensor([[ 0.1957,  0.9807, -2.7417]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.6178]])
# input_state: tensor([[ 0.2929,  0.9561, -2.0062]]), action: 0, action_logit: tensor([[1.]]), value: tensor([[0.4953]])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[286], line 4
#       1 model = PPO(state_size=env.observation_space.shape[0], action_size=env.action_space.shape[0]).to(device)
#       2 optimizer = optim.Adam(model.parameters(), lr=1e-3)
# ----> 4 scores = train(env, model, optimizer, epsilon=0.2, n_epochs=4, n_actors=4, batch_size=64, lr=1e-3, c1=1.0, c2=0.01, render=False, early_stop=False, n_episodes=1, max_t=1000, gamma=1.0, print_every=1)
#
# Cell In[285], line 22, in train(env, model, optimizer, epsilon, n_epochs, n_actors, batch_size, lr, c1, c2, render, early_stop, n_episodes, max_t, gamma, print_every)
#      20 # Recalculate the total reward applying discounted factor
#      21 discounts = [gamma ** i for i in range(len(rewards) + 1)]
# ---> 22 cum_discounted_rewards = [sum([discounts[j]*rewards[j+t] for j in range(len(rewards)-t) ]) for t in range(len(rewards))]
#      24 # # compute Advantage
#      25 # values = torch.cat(values)
#      26 # advantages = cum_discounted_rewards - values
#      28 buffer.append([state, action, action_logit, cum_discounted_rewards, values])
#
# KeyboardInterrupt:
